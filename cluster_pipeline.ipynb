# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA, KernelPCA
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.cluster import KMeans, OPTICS, SpectralClustering
import umap

# Read in dataset
daily = pd.read_csv('data/final_processed/daily_prices.csv', parse_dates=['date']).sort_values(['date','ticker']).set_index('date')
ratios = pd.read_csv('data/final_processed/firm_ratios.csv', parse_dates=['date']).sort_values(['date','ticker']).set_index('date')
sectors = pd.read_csv('data/final_processed/sectors.csv', parse_dates=['date']).sort_values(['date','ticker']).set_index('date')
short = pd.read_csv('data/final_processed/short_interest_rate.csv', parse_dates=['date']).sort_values(['date','ticker']).set_index('date')

# Merge
df = daily.merge(ratios, on=['ticker', 'date'])
df = df.merge(short, on =['ticker', 'date'])
df = df.merge(sectors, on=['ticker', 'date'])

# Define the date range of the dataset
start_date = '2002-01'
end_date = '2019-12'

# Create a date range with a customizable frequency
formation_period = '3M'
date_range = pd.date_range(start=start_date, end=end_date, freq=formation_period)

# Loop through all formation periods
results = []
for period_start in date_range:
    period_end = period_start + pd.tseries.offsets.DateOffset(months=int(formation_period[:-1]))
    df_period = df.loc[period_start.strftime('%Y-%m'):period_end.strftime('%Y-%m')]
    to_drop = df_period.loc[df_period.isna().any(axis=1)]['ticker'].unique()
    df_period = df_period.loc[~df_period['ticker'].isin(to_drop)]

    # Preprocessing steps
    df_train = df_period.reset_index().sort_values(['ticker', 'date'])
    idx = df_train[['ticker', 'date']]
    df_train = df_train.drop(['date','ticker'], axis=1)

    ohe_column = 'gicdesc'
    ohe_categories = df_train[ohe_column].unique().tolist()
    enc = OneHotEncoder(sparse_output=False, categories=[ohe_categories]) 
    transformer = make_column_transformer((enc, [ohe_column]), remainder='passthrough') 
    X_train = transformer.fit_transform(df_train)

    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)

    # Dimensionality reduction methods and clustering algorithms
    dim_reduction_methods = [
        {'name': 'PCA', 'method': PCA, 'params': {'n_components': [2, 3, 4]}},
        {'name': 'KPCA', 'method': KernelPCA, 'params': {'n_components': [2, 3, 4], 'kernel': ['linear', 'poly', 'rbf', 'sigmoid']}},
        {'name': 'UMAP', 'method': umap.UMAP, 'params': {'n_components': [2, 3, 4], 'n_neighbors': [5, 10, 15]}}
    ]

    clustering_algorithms = [
        {'name': 'KMeans', 'method': KMeans, 'params': {'n_clusters': [2, 3, 4, 5]}},
        # {'name': 'OPTICS', 'method': OPTICS, 'params': {'min_samples': [3, 5, 7]}},
        {'name': 'SpectralClustering', 'method': SpectralClustering, 'params': {'n_clusters': [2, 3, 4, 5]}}
    ]

    # Loop through combinations of dimensionality reduction and clustering methods
    for dr in dim_reduction_methods:
        for cl in clustering_algorithms:
            for dr_param_value in dr['params']['n_components']:
                reduced_data = dr['method'](n_components=dr_param_value).fit_transform(X_train)

                # Create a new df with components
                components_df = pd.DataFrame(data=reduced_data, columns=[f'pc {i+1}' for i in range(dr_param_value)])

                # Merge the principal components with indices then groupby tickers
                merged_df = pd.concat([idx.reset_index(drop=True), components_df], axis=1)
                grouped_df = merged_df.groupby('ticker')

                # Concatenate the components for each ticker into a single vector
                vecs = {}
                for ticker, group in grouped_df:
                    components = group[[f'pc {i+1}' for i in range(dr_param_value)]].values.T
                    vec_components = np.concatenate(components)
                    vecs[ticker] = vec_components

                # Create df with a single row for each ticker and vectorized components
                vectorized_df = pd.DataFrame(list(vecs.items()), columns=['ticker', 'components'])

                # Get mode of the vector lengths
                vector_lengths = [len(vector) for vector in vectorized_df['components']]
                lengths_series = pd.Series(vector_lengths)
                mode_length = lengths_series.mode().iloc[0]

                # Drop anything that doesn't have the right length components; should do it by mode of vector lengths
                for i, vector in enumerate(vectorized_df['components']):
                    if vector.shape != (mode_length,):
                        vectorized_df = vectorized_df.drop(i)

                # Extract the vectors from the vectorized_df DataFrame
                vectors = np.array([np.array(vector) for vector in vectorized_df['components']])

                for param_name, param_values in cl['params'].items():
                    for param_value in param_values:
                        clustering_method = cl['method'](**{param_name: param_value})
                        cluster_labels = clustering_method.fit_predict(vectors)
                        # Merge the labels with the indices
                        labeled_df = pd.concat([vectorized_df['ticker'].reset_index(drop=True), pd.Series(cluster_labels, name='cluster')], axis=1)

                        # Group the tickers by the assigned cluster labels
                        clusters = labeled_df.groupby('cluster')['ticker'].apply(list)

                        # Store the results
                        result = {
                            'period_start': period_start,
                            'period_end': period_end,
                            'dim_reduction_method': dr['name'],
                            'dim_reduction_params': {f'n_components': dr_param_value},
                            'clustering_algorithm': cl['name'],
                            'clustering_params': {param_name: param_value},
                            'clusters': clusters
                        }
                        results.append(result)

# Print the results
for r in results:
    print(f"Period: {r['period_start']} - {r['period_end']}")
    print(f"Dimensionality Reduction: {r['dim_reduction_method']} - {r['dim_reduction_params']}")
    print(f"Clustering Algorithm: {r['clustering_algorithm']} - {r['clustering_params']}")
    print("Clusters:")
    print(r['clusters'])
    print("\n")
# Out:
# /var/folders/pr/c3wk8t5n3q14vnms13t5jjmh0000gn/T/ipykernel_57915/2065095237.py:11: DtypeWarning: Columns (70) have mixed types. Specify dtype option on import or set low_memory=False.
#   ratios = pd.read_csv('data/final_processed/firm_ratios.csv', parse_dates=['date']).sort_values(['date','ticker']).set_index('date')
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited at iteration 1938 with accuracies
# [1.24660220e-12 1.28595854e-06 2.58316293e-06 6.13660366e-07
#  1.59042402e-06]
# not reaching the requested tolerance 1.6242265701293945e-06.
# Use iteration 1261 instead with accuracy
# 1.1792608949704428e-06.
#
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited postprocessing with accuracies
# [3.40037701e-13 1.06694412e-06 2.92719037e-06 2.34039591e-07
#  1.66813230e-06]
# not reaching the requested tolerance 1.6242265701293945e-06.
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited at iteration 2000 with accuracies
# [2.60671891e-11 3.25767781e-08 4.92971974e-07 1.02047699e-07
#  1.02531710e-06 4.42425229e-06]
# not reaching the requested tolerance 1.6242265701293945e-06.
# Use iteration 1671 instead with accuracy
# 7.512299371539306e-07.
#
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited postprocessing with accuracies
# [7.62346051e-13 3.27566335e-08 4.99623318e-07 1.05683632e-07
#  1.68146223e-06 2.18782502e-06]
# not reaching the requested tolerance 1.6242265701293945e-06.
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited at iteration 2000 with accuracies
# [2.92933642e-14 8.56563309e-07 1.28441421e-05]
# not reaching the requested tolerance 1.6242265701293945e-06.
# Use iteration 1246 instead with accuracy
# 9.698420803841815e-07.
#
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited postprocessing with accuracies
# [1.89800528e-15 6.11697742e-07 2.29756521e-06]
# not reaching the requested tolerance 1.6242265701293945e-06.
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited at iteration 2000 with accuracies
# [1.69903415e-14 6.74194467e-07 1.07467751e-06 3.00284463e-05]
# not reaching the requested tolerance 1.6242265701293945e-06.
# Use iteration 1871 instead with accuracy
# 3.433797671779445e-06.
#
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited postprocessing with accuracies
# [3.80829993e-15 3.93569551e-07 6.96155278e-07 1.26454687e-05]
# not reaching the requested tolerance 1.6242265701293945e-06.
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited at iteration 2000 with accuracies
# [5.29949752e-12 1.83883991e-07 1.01268946e-07 8.66103897e-07
#  6.95315894e-06]
# not reaching the requested tolerance 1.6242265701293945e-06.
# Use iteration 1531 instead with accuracy
# 6.754349735413604e-07.
#
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited postprocessing with accuracies
# [2.08063103e-13 1.87671882e-07 1.05287116e-07 9.82231439e-07
#  2.10197714e-06]
# not reaching the requested tolerance 1.6242265701293945e-06.
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited at iteration 2000 with accuracies
# [3.12982886e-11 2.48020779e-07 2.09493628e-07 5.88638756e-07
#  9.92595866e-07 2.51880067e-05]
# not reaching the requested tolerance 1.6242265701293945e-06.
# Use iteration 1080 instead with accuracy
# 6.316521133736109e-07.
#
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited postprocessing with accuracies
# [4.69896341e-13 2.62869394e-07 2.23806650e-07 4.56311853e-07
#  7.75345693e-07 2.07156146e-06]
# not reaching the requested tolerance 1.6242265701293945e-06.
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited at iteration 455 with accuracies
# [1.84742502e-15 2.06120750e-06 2.98651185e-06 2.79213860e-06
#  1.00889364e-05 4.59643082e-06]
# not reaching the requested tolerance 5.0514936447143555e-06.
# Use iteration 420 instead with accuracy
# 3.2292008617431304e-06.
#
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited postprocessing with accuracies
# [2.41498705e-15 2.11148370e-06 2.61699094e-06 2.44353842e-06
#  5.44206712e-06 6.76112501e-06]
# not reaching the requested tolerance 5.0514936447143555e-06.
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited at iteration 681 with accuracies
# [3.07919678e-15 1.86323482e-06 9.39027783e-06 4.80340800e-06]
# not reaching the requested tolerance 5.170702934265137e-06.
# Use iteration 578 instead with accuracy
# 2.7149713657175983e-06.
#
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited postprocessing with accuracies
# [2.11520286e-15 2.37398735e-06 2.86625550e-06 5.61964264e-06]
# not reaching the requested tolerance 5.170702934265137e-06.
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited at iteration 2000 with accuracies
# [2.02881441e-14 4.81044138e-07 2.20812899e-05]
# not reaching the requested tolerance 1.6689300537109375e-06.
# Use iteration 1166 instead with accuracy
# 2.9466848657910086e-06.
#
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited postprocessing with accuracies
# [1.18152985e-14 4.87394888e-07 8.35265970e-06]
# not reaching the requested tolerance 1.6689300537109375e-06.
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited at iteration 2000 with accuracies
# [5.65134586e-13 3.44916821e-07 4.07144480e-07 1.29652390e-05]
# not reaching the requested tolerance 1.6689300537109375e-06.
# Use iteration 833 instead with accuracy
# 2.273266624558429e-06.
#
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited postprocessing with accuracies
# [2.14170775e-14 3.45920583e-07 4.87200574e-07 8.25994732e-06]
# not reaching the requested tolerance 1.6689300537109375e-06.
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited at iteration 15 with accuracies
# [4.27473538e-13 1.09381199e-05 8.16047848e-07]
# not reaching the requested tolerance 1.6689300537109375e-06.
# Use iteration 15 instead with accuracy
# 3.918056050267305e-06.
#
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited postprocessing with accuracies
# [6.61152200e-15 1.09381200e-05 8.16046466e-07]
# not reaching the requested tolerance 1.6689300537109375e-06.
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited at iteration 2000 with accuracies
# [3.82020654e-15 5.21501218e-07 7.68931936e-06]
# not reaching the requested tolerance 1.6689300537109375e-06.
# Use iteration 1516 instead with accuracy
# 1.0951357433798128e-06.
#
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited postprocessing with accuracies
# [2.40941321e-15 3.04547339e-07 2.98432453e-06]
# not reaching the requested tolerance 1.6689300537109375e-06.
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited at iteration 2000 with accuracies
# [1.29490213e-12 7.26769946e-07 4.13430403e-07 1.60012526e-06
#  1.67766682e-05]
# not reaching the requested tolerance 1.6689300537109375e-06.
# Use iteration 1980 instead with accuracy
# 1.6045913324069582e-06.
#
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited postprocessing with accuracies
# [1.75696350e-14 7.26921017e-07 4.14210085e-07 7.83856076e-07
#  6.09796791e-06]
# not reaching the requested tolerance 1.6689300537109375e-06.
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited at iteration 485 with accuracies
# [1.48903261e-15 2.51264294e-06 2.13889645e-06 7.04810968e-06
#  5.17770119e-06]
# not reaching the requested tolerance 5.304813385009766e-06.
# Use iteration 485 instead with accuracy
# 3.3754700534430548e-06.
#
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited postprocessing with accuracies
# [2.63297671e-15 2.51264281e-06 2.13889633e-06 7.04810898e-06
#  5.17770226e-06]
# not reaching the requested tolerance 5.304813385009766e-06.
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited at iteration 516 with accuracies
# [2.13703804e-15 2.43149198e-06 2.49833432e-06 3.12604735e-06
#  7.64894372e-06 4.42088700e-06]
# not reaching the requested tolerance 5.334615707397461e-06.
# Use iteration 468 instead with accuracy
# 2.6141510678441835e-06.
#
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited postprocessing with accuracies
# [2.81400740e-15 1.56144415e-06 1.92570386e-06 2.64978691e-06
#  3.51288347e-06 6.03508777e-06]
# not reaching the requested tolerance 5.334615707397461e-06.
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited at iteration 2000 with accuracies
# [6.08308567e-13 6.43512191e-07 4.80140858e-06 5.37671703e-07
#  2.66203559e-05]
# not reaching the requested tolerance 1.6838312149047852e-06.
# Use iteration 1461 instead with accuracy
# 4.287990003754733e-06.
#
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited postprocessing with accuracies
# [1.80136823e-14 6.64352514e-07 5.07436622e-06 3.87762282e-07
#  1.53129429e-05]
# not reaching the requested tolerance 1.6838312149047852e-06.
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited at iteration 927 with accuracies
# [3.12680570e-13 1.49527931e-07 3.36224585e-07 2.88494042e-07
#  3.19802731e-06 1.51760262e-06]
# not reaching the requested tolerance 1.6838312149047852e-06.
# Use iteration 315 instead with accuracy
# 7.81359846587658e-07.
#
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited postprocessing with accuracies
# [8.71571005e-15 1.83161957e-07 4.30738086e-07 4.06541594e-07
#  1.11221470e-06 2.55550244e-06]
# not reaching the requested tolerance 1.6838312149047852e-06.
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited at iteration 2000 with accuracies
# [4.50742862e-15 8.57249628e-07 6.57256236e-06]
# not reaching the requested tolerance 1.6838312149047852e-06.
# Use iteration 1995 instead with accuracy
# 1.165367370819205e-06.
#
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited postprocessing with accuracies
# [1.11168902e-15 8.40134986e-07 2.65596713e-06]
# not reaching the requested tolerance 1.6838312149047852e-06.
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (4) found smaller than n_clusters (5). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited at iteration 2000 with accuracies
# [4.06783455e-14 1.17206816e-06 7.26447633e-07 1.98341939e-05]
# not reaching the requested tolerance 1.6838312149047852e-06.
# Use iteration 1679 instead with accuracy
# 4.135786738871204e-06.
#
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:393: UserWarning: Exited postprocessing with accuracies
# [3.04992605e-14 1.14277297e-06 7.24434580e-07 1.46759391e-05]
# not reaching the requested tolerance 1.6838312149047852e-06.
#   _, diffusion_map = lobpcg(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (3). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:420: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   est = KMeans(
# /Users/danielisaacgold/miniconda3/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:274: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
